# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('/content/START-UP_sheet.csv')

# %%
df.shape
# Out:
# (102, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.                     102 non-null    int64
#  1   Company                 102 non-null    object
#  2   Sector                  102 non-null    object
#  3   Entry Valuation^^ ($B)  102 non-null    float64
#  4   Valuation ($B)          102 non-null    float64
#  5   Entry                   102 non-null    object
#  6   Location                102 non-null    object
#  7   Select Investors        102 non-null    object
#  8   sequoia capital         102 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 7.3+ KB

# %%
df.drop(columns=['No.'],inplace=True)

# %%
df.rename(columns={'Entry Valuation^^ ($B)':'EntryValuation', 'Valuation ($B)':'Valuation', 'Entry':'EntryDate', 'Select Investors':'Investors'},inplace=True)

# %%
df['CurrentDate'] = datetime.today().strftime('%b-%Y')

# %%
df['EntryDate'] = df['EntryDate'].astype("string")

# %%
NewEntryDate = []
for i in df['EntryDate']:
  idx = 0
  cd = i.split('-')
  cd.insert(1,'-')
  cd.insert(2,'20')
  # print("".join(cd))
  NewEntryDate.insert(idx,"".join(cd))
  idx = idx+1;

# %%
NewEntryDate.reverse()
NewEntryDate
# Out:
# ['Sep-2011',
#  'Feb-2012',
#  'Feb-2013',
#  'Oct-2014',
#  'Feb-2015',
#  'Mar-2015',
#  'Apr-2015',
#  'Sep-2015',
#  'Jan-2016',
#  'Aug-2016',
#  'Jan-2018',
#  'Apr-2018',
#  'Jun-2018',
#  'Jun-2018',
#  'Jul-2018',
#  'Sep-2018',
#  'Sep-2018',
#  'Nov-2018',
#  'Jan-2019',
#  'Feb-2019',
#  'Mar-2019',
#  'Apr-2019',
#  'Jun-2019',
#  'Jul-2019',
#  'Jul-2019',
#  'Jul-2019',
#  'Sep-2019',
#  'Jan-2020',
#  'Mar-2020',
#  'Jun-2020',
#  'Sep-2020',
#  'Oct-2020',
#  'Nov-2020',
#  'Dec-2020',
#  'Dec-2020',
#  'Dec-2020',
#  'Dec-2020',
#  'Jan-2021',
#  'Feb-2021',
#  'Feb-2021',
#  'Mar-2021',
#  'Mar-2021',
#  'Apr-2021',
#  'Apr-2021',
#  'Apr-2021',
#  'Apr-2021',
#  'Apr-2021',
#  'Apr-2021',
#  'Apr-2021',
#  'Apr-2021',
#  'May-2021',
#  'May-2021',
#  'Jun-2021',
#  'Jul-2021',
#  'Jul-2021',
#  'Jul-2021',
#  'Aug-2021',
#  'Aug-2021',
#  'Aug-2021',
#  'Aug-2021',
#  'Aug-2021',
#  'Aug-2021',
#  'Aug-2021',
#  'Sep-2021',
#  'Sep-2021',
#  'Sep-2021',
#  'Oct-2021',
#  'Oct-2021',
#  'Oct-2021',
#  'Oct-2021',
#  'Oct-2021',
#  'Nov-2021',
#  'Nov-2021',
#  'Nov-2021',
#  'Nov-2021',
#  'Nov-2021',
#  'Nov-2021',
#  'Nov-2021',
#  'Dec-2021',
#  'Dec-2021',
#  'Dec-2021',
#  'Jan-2022',
#  'Jan-2022',
#  'Jan-2022',
#  'Jan-2022',
#  'Feb-2022',
#  'Feb-2022',
#  'Feb-2022',
#  'Feb-2022',
#  'Feb-2022',
#  'Feb-2022',
#  'Mar-2022',
#  'Mar-2022',
#  'Mar-2022',
#  'Mar-2022',
#  'May-2022',
#  'Jun-2022',
#  'Jun-2022',
#  'Jun-2022',
#  'Jul-2022',
#  'Aug-2022',
#  'Sep-2022']

# %%
df['NewEntryDate'] = NewEntryDate

# %%
df.drop(columns=['EntryDate'],inplace=True)

# %%
df["CurrentDate"] = pd.to_datetime(df["CurrentDate"])
df["NewEntryDate"] = pd.to_datetime(df["NewEntryDate"])
df['Interval'] = df["CurrentDate"] - df["NewEntryDate"]
df['ValuationGrowth'] = df["Valuation"] - df["EntryValuation"]

# %%
df['Interval'] = df['Interval'].apply(lambda x: x.days)
# df['NewEntryDate'] = df['NewEntryDate'].apply(lambda x: x.split('-').insert(1,'-').insert(2,'20').join())

# %%
df.rename(columns={'Interval':'DayInterval'},inplace=True)

# %%
df['GrowthRate(PerMonth)'] = df['ValuationGrowth']/(df['DayInterval']/30)
df['GrowthRate(PerYear)'] = df['ValuationGrowth']/(df['DayInterval']/365)

# %%
df.head()
# Out:
#      Company                       Sector  EntryValuation  Valuation  \
# 0     InMobi          Adtech - Mobile Ads             1.0        1.0
# 1  Flipkart^                   E-Commerce             1.0       37.6
# 2   Mu Sigma             SaaS - Analytics             1.0        1.5
# 3  Snapdeal*                   E-Commerce             1.8        2.4
# 4     PayTM^  Fintech - Payments & Wallet             1.7       16.0
#
#               Location                                          Investors  \
# 0  Bangalore/Singapore                  KPCB, Sherpalo Ventures, SoftBank
# 1  Bangalore/Singapore    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2    Bangalore/Chicago           Accel, Sequoia Capital, General Atlantic
# 3                Delhi  Kalaari Capital, Nexus Ventures, Bessemer, Sof...
# 4                Noida  Saama Capital, Elevation Capital, Alibaba, Ber...
#
#   sequoia capital CurrentDate NewEntryDate  DayInterval  ValuationGrowth  \
# 0         #VALUE!  2023-11-01   2011-09-01         4444              0.0
# 1              no  2023-11-01   2012-02-01         4291             36.6
# 2              no  2023-11-01   2013-02-01         3925              0.5
# 3              no  2023-11-01   2014-10-01         3318              0.6
# 4              no  2023-11-01   2015-02-01         3195             14.3
#
#    GrowthRate(PerMonth)  GrowthRate(PerYear)
# 0              0.000000             0.000000
# 1              0.255884             3.113260
# 2              0.003822             0.046497
# 3              0.005425             0.066004
# 4              0.134272             1.633646

# %%
TopGrowingStartups = df.sort_values(by=['GrowthRate(PerMonth)'],ascending=False)[['Company','GrowthRate(PerYear)']].head()
TopGrowingStartups
# Out:
#       Company  GrowthRate(PerYear)
# 10      BYJUS             3.598592
# 1   Flipkart^             3.113260
# 33   PhonePe^             2.227700
# 31   RazorPay             2.107016
# 12     Swiggy             1.715260

# %%
pps = plt.barh(y=TopGrowingStartups['Company'],width=TopGrowingStartups['GrowthRate(PerYear)'],label='Top Growing Companies')
for p in pps:
  # print(p.get_width(),p.get_y()+p.get_height())
  plt.text(p.get_width()+0.2,p.get_y()+p.get_height()/5,round(p.get_width(),2),rotation=-90)
plt.legend()
plt.xlabel("Valuation in Billons($) Per Month")
plt.ylabel("Top 5 Companies")
plt.title('Top 5 Startup With Higher Growth Rate')
plt.show()

# %%
popComp = df.groupby(['Sector']).agg(CompanyCount=('Company','count'),CumulativeGrowth=('GrowthRate(PerYear)','mean'))
popComp['CompanyCount'].describe()
# Out:
# count    75.000000
# mean      1.360000
# std       0.816055
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       5.000000
# Name: CompanyCount, dtype: float64

# %%
popCompMask = popComp['CompanyCount']>2
popComp = popComp[popCompMask]
popComp
# Out:
#                          CompanyCount  CumulativeGrowth
# Sector
# E-Commerce                          4          0.844019
# Edtech                              5          0.846016
# Gaming                              3          0.508458
# Logistics Services                  4          0.072380
# Marketplace - Used Cars             4          0.229167

# %%
plt.plot(popComp,marker='o')
xLabels = ['E-commerce','Ed-Tech','Gaming','MarketPlace','Logistics']
plt.xticks(np.arange(5),xLabels,rotation=-30)
plt.legend(labels=['Company Count','Cumulative Growth'])
plt.grid()
plt.xlabel('Domains of Company')
plt.ylabel('Values in Numbers')
plt.title('Popular Domain Trends')
# Out:
# Text(0.5, 1.0, 'Popular Domain Trends')

# %%
# df.groupby(['NewEntryDate']).agg(CompCount=('Company','count'),ValuationInvestment=('EntryValuation','sum'))
EntryYearData = df['NewEntryDate'].apply(lambda x:x.year)
df.insert(loc=6, column='EntryYear', value=EntryYearData)

# %%
DatewiseData = df.groupby(['EntryYear']).agg(CompanyCount=('Company','count'),TotalInvestments=('EntryValuation','sum'))
DatewiseData['AvgInvestment'] = DatewiseData['TotalInvestments'] / DatewiseData['CompanyCount']
DatewiseData
# Out:
#            CompanyCount  TotalInvestments  AvgInvestment
# EntryYear
# 2011                  1              1.00       1.000000
# 2012                  1              1.00       1.000000
# 2013                  1              1.00       1.000000
# 2014                  1              1.80       1.800000
# 2015                  4              5.30       1.325000
# 2016                  2              2.50       1.250000
# 2018                  8             14.30       1.787500
# 2019                  9             10.10       1.122222
# 2020                 10             16.70       1.670000
# 2021                 44             68.07       1.547045
# 2022                 21             36.08       1.718095

# %%
pps = plt.bar(x=DatewiseData.index,height=DatewiseData['TotalInvestments'],label='Investments in Billons($)',width=0.4)
for p in pps:
  # print(p.get_width(),p.get_y()+p.get_height())
  plt.text(p.get_x(), p.get_height()+0.8, round(p.get_height()))
plt.grid()
plt.legend()
plt.xlabel("Years")
plt.ylabel("Investments")
plt.title('Valuations Trends')
plt.plot(DatewiseData.index,DatewiseData['TotalInvestments'],color='red',marker='o')
plt.show()

# %%
plt.plot(DatewiseData.index,DatewiseData['AvgInvestment'],color='green',marker='o')
plt.xlabel("Years")
plt.ylabel("Avg Invetments in Billons($)")
plt.title('Avg. Valuations Trends')
plt.legend(['Avg. Investments'])
plt.grid()

# %%
plt.plot(DatewiseData.index,DatewiseData['CompanyCount'],color='red',marker='o')
plt.xlabel("Years")
plt.ylabel("Number of Companies")
plt.title('Investment in Companies')
plt.legend(['Number of Investments'])
plt.grid()

# %%
testData = []
def makeLocList(data):
  testData.extend(data.split('/'))
df['Location'].apply(lambda x:makeLocList(x))
uniqueLocations = np.unique(np.array(testData))
uniqueLocations

# df['Location'] = df['Location'].apply(lambda x:x.split('/')[0])
# Out:
# array(['Bangalore', 'Bellevue', 'Chennai', 'Chicago', 'Delhi', 'Dublin',
#        'Goa', 'Gurgaon', 'Hyderabad', 'Jaipur', 'Mumbai', 'New York',
#        'Noida', 'Palo Alto', 'Princeton', 'Pune', 'San Francisco',
#        'San Mateo', 'Singapore', 'Sunnyvale', 'Thane'], dtype='<U13')

# %%
df.head()
# Out:
#      Company                       Sector  EntryValuation  Valuation  \
# 0     InMobi          Adtech - Mobile Ads             1.0        1.0
# 1  Flipkart^                   E-Commerce             1.0       37.6
# 2   Mu Sigma             SaaS - Analytics             1.0        1.5
# 3  Snapdeal*                   E-Commerce             1.8        2.4
# 4     PayTM^  Fintech - Payments & Wallet             1.7       16.0
#
#               Location                                          Investors  \
# 0  Bangalore/Singapore                  KPCB, Sherpalo Ventures, SoftBank
# 1  Bangalore/Singapore    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2    Bangalore/Chicago           Accel, Sequoia Capital, General Atlantic
# 3                Delhi  Kalaari Capital, Nexus Ventures, Bessemer, Sof...
# 4                Noida  Saama Capital, Elevation Capital, Alibaba, Ber...
#
#    EntryYear sequoia capital CurrentDate NewEntryDate  DayInterval  \
# 0       2011         #VALUE!  2023-11-01   2011-09-01         4444
# 1       2012              no  2023-11-01   2012-02-01         4291
# 2       2013              no  2023-11-01   2013-02-01         3925
# 3       2014              no  2023-11-01   2014-10-01         3318
# 4       2015              no  2023-11-01   2015-02-01         3195
#
#    ValuationGrowth  GrowthRate(PerMonth)  GrowthRate(PerYear)
# 0              0.0              0.000000             0.000000
# 1             36.6              0.255884             3.113260
# 2              0.5              0.003822             0.046497
# 3              0.6              0.005425             0.066004
# 4             14.3              0.134272             1.633646

# %%
LocationwiseData = df.groupby(['Location']).agg(CompanyCount=('Company','count'),TotalInvestments=('EntryValuation','sum'))
LocationwiseData['AvgInvestment'] = LocationwiseData['TotalInvestments'] / LocationwiseData['CompanyCount']
LocationwiseData
# Out:
#                          CompanyCount  TotalInvestments  AvgInvestment
# Location
# Bangalore                          34             56.70       1.667647
# Bangalore/Chicago                   1              1.00       1.000000
# Bangalore/San Francisco             3              4.60       1.533333
# Bangalore/Singapore                 3              3.00       1.000000
# Chennai                             2              2.70       1.350000
# Chennai/Palo Alto                   1              2.50       2.500000
# Chennai/San Francisco               1              1.40       1.400000
# Chennai/San Mateo                   1              1.50       1.500000
# Delhi                               7             11.53       1.647143
# Goa                                 1              1.53       1.530000
# Gurgaon                            14             20.37       1.455000
# Hyderabad/Bellevue                  1              1.00       1.000000
# Hyderabad/Singapore                 1              1.00       1.000000
# Jaipur                              2              2.82       1.410000
# Mumbai                             12             18.30       1.525000
# Mumbai/Dublin                       1              4.00       4.000000
# Mumbai/New York                     1              1.00       1.000000
# Mumbai/Princeton                    1              1.10       1.100000
# Mumbai/San Francisco                1              1.40       1.400000
# Mumbai/Singapore                    1              3.20       3.200000
# Noida                               4              6.30       1.575000
# Noida/San Francisco                 1              1.30       1.300000
# Noida/Singapore                     1              1.00       1.000000
# Pune                                4              5.60       1.400000
# Pune/Bellevue                       1              1.00       1.000000
# Pune/Sunnyvale                      1              1.00       1.000000
# Thane                               1              1.00       1.000000

# %%
plt.plot(LocationwiseData.index,LocationwiseData['CompanyCount'],color='red',marker='o')
plt.xlabel("Cities")
plt.ylabel("Number of Companies")
plt.title('Count of Investment in Cities')
plt.legend(['Number of Investments'])
plt.xticks(rotation=-30)
plt.grid()

# %%
plt.plot(LocationwiseData.index,LocationwiseData['TotalInvestments'],color='green',marker='o')
plt.xlabel("Cities")
plt.ylabel("Investment in Billions($)")
plt.title('Total Investment in Cities')
plt.legend(['Amount of Investments'])
plt.xticks(rotation=-30)
plt.grid()

# %%
plt.plot(LocationwiseData.index,LocationwiseData['AvgInvestment'],color='blue',marker='o')
plt.xlabel("Cities")
plt.ylabel("Investment in Billions($)")
plt.title('Avg Investment in Cities')
plt.legend(['Amount of Investments'])
plt.xticks(rotation=-30)
plt.grid()

# %%
Investors = []
def AllInvestors(invs):
  Investors.extend(invs.split(', '))

df['Investors'].apply(lambda x:AllInvestors(x))

Investors = np.array(Investors)\

Investors
# Out:
# array(['KPCB', 'Sherpalo Ventures', 'SoftBank', 'Accel', 'Tiger Global',
#        'Naspers', 'SoftBank', 'Tencent', 'Accel', 'Sequoia Capital',
#        'General Atlantic', 'Kalaari Capital', 'Nexus Ventures',
#        'Bessemer', 'SoftBank', 'Alibaba', 'Saama Capital',
#        'Elevation Capital', 'Alibaba', 'Berkshire Hathway',
#        'Tiger Global', 'Matrix Partners', 'Steadview', 'SoftBank',
#        'Tencent', 'Matrix Partners', 'Omidyar Network', 'Norwest',
#        'Kinnevik', 'Steadview Capital', 'Info Edge', 'Sequoia Capital',
#        'Vy Capital', 'Alibaba', 'Steadview Capital', 'Nexus Ventures',
#        'Helion Ventures', 'Beenos', 'Tiger Global', 'Others',
#        'Tiger Global', 'Tencent', 'Foxconn', 'Aarin Capital',
#        'Sequoia Capital', 'Lightspeed Ventures', 'Tencent',
#        'General Atlantic', 'Tiger Global', 'Elevation Capital', 'Alibaba',
#        'SoftBank', 'eBay', 'Accel', 'Elevation Capital', 'Norwest',
#        'Naspers', 'Tencent', 'Invesco', 'Info Edge', 'Intel',
#        'Inventus Capital', 'Tiger Global', 'SoftBank', 'Tencent',
#        'Steadview Capital', 'Accel', 'Tiger Global', 'Google',
#        'Sequoia Capital', 'Steadview Capital', 'Lightspeed Ventures',
#        'Sequoia Capital', 'SoftBank', 'Lightspeed Ventures', 'DST Global',
#        'Tencent', 'SIDBI VC', 'TA Associates', 'General Atlantic',
#        'Nexus Ventures', 'Multiples PE', 'Tiger Global', 'Carlyle',
#        'SoftBank', 'Fosun Group', 'Steadview Capital',
#        'Elevation Capital', 'Warburg Pincus', 'Ascent Capital',
#        'Helion Ventures', 'Bessemer', 'IFC', 'Alibaba', 'Kalaari Capital',
#        'Tencent', 'Multiples PE', 'Steadview', 'Alpha Wave Global',
#        'WestBridge', 'Nexus Ventures', 'Sequoia Capital', 'Eight Roads',
#        'B Capital', 'PremjiInvest', 'General Atlantic', 'Baring Asia',
#        'SoftBank', 'Tiger Global', 'Matrix Partners', 'SoftBank',
#        'Kedaara Capital', 'TPG', 'Chiratae Ventures', 'TR Capital',
#        'Sequoia Capital India', 'New Atlantic Ventures',
#        'Altimeter Capital', 'Temasek', 'Mastercard', 'Techpro Ventures',
#        'TVS Capital', 'Sharrp Ventures', 'TPG Growth',
#        'Steadview Capital', 'Nexus Ventures', 'Charles River Ventures',
#        'Insight Venture Partners', 'Blume Ventures',
#        'Nexus Venture Partners', 'Sequoia Capital India',
#        'Elevation Capital', 'General Atlantic', 'SoftBank',
#        'Steadview Capital', 'Matrix Partners India', 'Tiger Global',
#        'Sequoia Capital India', 'DST Global', 'Asia Venture Group',
#        'Apoletto', 'Unbound', 'DST Global', 'Sequoia Capital India',
#        'Alpha Wave Global', 'Tiger Global', 'Tencent', 'Accel India',
#        'Norwest', 'Tiger Global', 'Steadview Capital',
#        'Advent International', 'Matrix Partners India', 'Omidyar Network',
#        'Sequoia Capital India', 'Alpha Wave Global', 'CPPIB',
#        'Mithril Capital', 'Google', 'Fairfax Holdings', 'A91 Partners',
#        'Faering Capital', 'TVS Capital', 'WestBridge',
#        'Lightspeed Ventures', 'M12 (Microsoft)', 'Tiger Global',
#        'Steadview Capital', 'Accel India', 'Nexus Venture Partners',
#        'Tiger Global', 'Evolvence India', 'Matrix Partners India',
#        'Sequoia Capital India', 'Norwest', 'Morgan Stanley',
#        'TPG Capital', 'Chiratae Ventures', 'Elevation Capital', 'Vertex',
#        'SoftBank', 'Sequoia Capital India', 'Elevation Capital',
#        'SoftBank', 'Naspers', 'Sequoia Capital India', 'Ribbit Capital',
#        'DST Global', 'Alpha Wave Global', 'Orios VP',
#        'Eight Roads Ventures', 'Temasek', 'Naspers', 'Steadview Capital',
#        'Sequoia Capital India', 'Y Combinator', 'Tiger Global',
#        'Ribbit Capital', 'India Quotient', 'Elevation Capital',
#        'Lightspeed Ventures', 'Tiger Global', 'Twitter', 'Tiger Global',
#        'Charles River Ventures', 'Helion Ventures', 'Tiger Global',
#        'Steadview Capital', 'Sapphire Ventures', 'Accel India',
#        'Insight Venture Partners', 'Tiger Global', 'Steadview Capital',
#        'Accel India', 'Elevation Capital', 'Vy Capital',
#        'Prosus Ventures', 'Accel India', 'Jungle Ventures',
#        'Tiger Global', 'Sequoia Capital India', 'IFC', 'SoftBank',
#        'Mastercard', 'Accel', 'Bond Capital', 'Insight Venture Partners',
#        'Accel India', 'Sequoia Capital India', 'Sands Capital', 'IFC',
#        'Tiger Global', 'Beenos Partners', 'Lightbox',
#        'Axis Capital Partners', 'Beenext', 'SoftBank', 'Tiger Global',
#        'Matrix Partners India', 'Zodius Capital', 'Alpha Wave Global',
#        'Beenext', 'Sequoia Capital India', 'Tiger Global',
#        'Steadview Capital', 'SoftBank', 'Accel India',
#        'Qualcomm Ventures', 'Norwest', 'Temasek', 'IFC', 'Lupa Systems',
#        'B Capital', 'Coinbase Ventures', 'Polychain Capital', 'SoftBank',
#        'Accel', 'Sequoia Capital India', 'Bertelsmann India Investments',
#        'Tiger Global', 'Sequoia Capital India', 'SoftBank', 'Apoletto',
#        'Zomato', 'Kae Capital', 'Sequoia Capital India', 'Accel India',
#        'Lightspeed Ventures', 'D1 Capital Partners',
#        'Sequoia Capital India', 'Beenext', 'Moore Strategic Ventures',
#        'RTP Global', 'VH Capital', 'Sequoia Capital India',
#        'Lightspeed Ventures', 'Tiger Global', 'Insight Venture Partners',
#        'Accel India', 'Tiger Global', 'Omidyar Network', 'WestBridge',
#        'ABC World Asia', 'Mayfield', '3ONE4 Capital', 'Sistema Asia Fund',
#        'Bertelsmann India', 'Vertex', 'Multiples PE', 'Tiger Global',
#        'Sequoia Capital India', 'Ribbit Capital', 'Andreessen Horowitz',
#        'Coinbase Ventures', 'Sequoia Capital India', 'Lightbox',
#        'Coatue Management', 'RTP Global', 'QIA', 'Evolvence India',
#        'Sequoia Capital India', 'Hillhouse Capital', 'CapitalG',
#        'LeapFrog', 'Accel India', 'Elevation Capital', 'Amazon',
#        'General Atlantic', 'Multiples PE', 'Amazon', 'Ascent Capital',
#        'Bessemer', 'Accel India', 'Wipro Ventures', 'Kalaari Capital',
#        'Accel India', 'Kalaari Capital', 'Chiratae Ventures', 'Zomato',
#        'Temasek', 'Endiya Partners', 'Tiger Global', 'Alpha Wave Global',
#        'Accel India', 'Norwest', 'Prosus Ventures', 'Tiger Global',
#        'General Atlantic', 'Elevation Capital', 'Beenext',
#        'Moore Strategic Ventures', 'Tiger Global', 'Blume Ventures',
#        'General Catalyst Partners', 'Elevation Capital', 'Accel India',
#        'Tiger Global', 'Ratan Tata', 'Kalaari Capital', 'Tiger Global',
#        'Blume Ventures', 'Das Capital', 'Simile Venture Partners',
#        'Gunosy Capital', 'Tiger Global', 'Sequoia Capital India',
#        'Hummingbird Ventures', 'Epiq Capital', 'Sequoia Capital India',
#        'Sofina', 'Sharrp Ventures', 'Fireside Ventures', 'PremjiInvest',
#        'SoftBank Corp', 'TPG Capital', 'Steadview Capital', 'TPG Capital',
#        'TA Associates', 'Khazanah', 'Apax Partners', 'GSV Ventures',
#        'WestBridge', 'Elevar Equity', 'TPG Growth', '3ONE4 Capital',
#        'Lightspeed Ventures', 'Sequoia Capital India', 'TCV',
#        'Endiya Partners', 'Whiteboard Capital', 'Z3Partners',
#        'Alpha Wave Global', 'Matrix Partners India', 'Tiger Global',
#        'Coinbase Ventures', 'Sequoia Capital India', 'Tiger Global',
#        'SoftBank', 'SoftBank', 'Goldman Sachs', 'Prosus Ventures',
#        'Kalaari Capital', 'Avataar Venture Partners', 'KKR',
#        'Jungle Ventures', 'TPG Growth', 'Bessemer', 'Goldman Sachs',
#        'InvestCorp Group', 'Norwest', 'Gaja Capital', 'TPG Growth',
#        'ChrysCapital', 'Iron Pillar', 'March Capital',
#        'Chiratae Ventures', 'NEA', 'Lightspeed Ventures',
#        'Nexus Venture Partners', 'Vertex', 'Strive VC', 'B Capital Group',
#        'Insight Venture Partners', ' Lightrock India', 'TVS Capital',
#        'Avataar Venture Partners', 'PremjiInvest', 'Accel India',
#        'Norwest', 'Alpha Wave Global', 'Matrix Partners India',
#        'Tiger Global', 'Norwest', 'Tiger Global', 'Malabar Investments',
#        ' The Raine Group', '3ONE4 Capital', 'Tiger Global', 'Temasek',
#        'Speedinvest', 'GSV Ventures', 'WestBridge', 'JSW Ventures',
#        'IvyCap Ventures', 'Blume Ventures', 'Kedaara Capital',
#        'Stakeboat Capital', 'Gaja Capital', 'WestBridge', 'QED Investors',
#        'Matrix Partners India', 'Sequoia Capital India',
#        'Lightrock India', 'Info Edge', 'Tribe Capital', 'Temasek',
#        'Temasek', 'Motilal Oswal'], dtype='<U29')

# %%
InvestorsData = pd.DataFrame({'InvestorCompany':Investors})
InvestorsData.groupby(['InvestorCompany']).agg(InvestedCompCnt=('InvestorCompany','count')).describe()
TopFiveInvestors = InvestorsData.groupby(['InvestorCompany']).agg(InvestedCompCnt=('InvestorCompany','count')).sort_values(by='InvestedCompCnt',ascending=False).head()
TopFiveInvestors
# Out:
#                        InvestedCompCnt
# InvestorCompany
# Tiger Global                        38
# Sequoia Capital India               25
# SoftBank                            20
# Accel India                         15
# Steadview Capital                   14

# %%
plt.pie(TopFiveInvestors['InvestedCompCnt'],autopct='%1.1f%%',labels=TopFiveInvestors.index,textprops=dict(color="w"))
plt.legend()

# %%
TopFiveInvestors.index
# Out:
# Index(['Tiger Global', 'Sequoia Capital India', 'SoftBank', 'Accel India',
#        'Steadview Capital'],
#       dtype='object', name='InvestorCompany')
